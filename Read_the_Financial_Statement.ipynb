# %% [markdown]
# # Reading the Financial Statement using Python

# %%
import yfinance as yf

#import libraries

# %% [markdown]
# # Balance Sheet

# %%
# Create the functions forget access for balance sheet
def get_balance_sheet_data(symbol):
    # for company symbol
    company = yf.Ticker(symbol)
    # get access of balancesheet
    balance_sheet = company.balance_sheet
    return balance_sheet

symbol = "TCS"
# balance sheet
balance_sheet_data = get_balance_sheet_data(symbol)
balance_sheet_data
# Out:
#                                                    2023-03-31   2022-03-31  \
# Ordinary Shares Number                             49181562.0   49635447.0
# Share Issued                                       49181562.0   49635447.0
# Net Debt                                          160913000.0  148198000.0
# Total Debt                                        539172000.0  532335000.0
# Tangible Book Value                                17460000.0  -18001000.0
# ...                                                       ...          ...
# Loans Receivable                                          NaN    9308000.0
# Accounts Receivable                                25870000.0   30225000.0
# Cash Cash Equivalents And Short Term Investments    6958000.0   14252000.0
# Cash And Cash Equivalents                           6958000.0   14252000.0
# Cash Financial                                      6958000.0   14252000.0
#
# ...

# %% [markdown]
# # Cash Flow Statement

# %%
# Create the function for cash Flow statement
def get_cash_flow_data(symbol):
    company = yf.Ticker(symbol)
    cash = company.cash_flow
    return cash

symbol = "TCS" # Change the comapny symbol as per your requirement
get_cash_flow_data = get_cash_flow_data(symbol)
get_cash_flow_data
# Out:
#                                                  2023-03-31   2022-03-31  \
# Free Cash Flow                                   -4918000.0   23601000.0
# Repurchase Of Capital Stock                      -5000000.0          NaN
# Repayment Of Debt                              -116589000.0 -118436000.0
# Issuance Of Debt                                120292000.0  113167000.0
# Capital Expenditure                             -64223000.0  -33389000.0
# Interest Paid Supplemental Data                  13688000.0   10745000.0
# Income Tax Paid Supplemental Data                21275000.0   30163000.0
# End Cash Position                                 6958000.0   14252000.0
# Beginning Cash Position                          14252000.0   17687000.0
# Effect Of Exchange Rate Changes                   -519000.0    -622000.0
# Changes In Cash                                  -6775000.0   -2813000.0
# Financing Cash Flow                              -1669000.0   -9381000.0
# ...

# %% [markdown]
# # Income Statement

# %%
# Create the function for Income Statement
def get_income_statement_data(symbol):
    company = yf.Ticker(symbol)
    inc = company.financials
    return inc

symbol = "TCS" # Change the comapny symbol as per your requirement
get_income_statement_data = get_income_statement_data(symbol)
get_income_statement_data
# Out:
#                                                       2023-03-31  \
# Tax Effect Of Unusual Items                          -79133600.0
# Tax Rate For Calcs                                           0.4
# Normalized EBITDA                                    109144000.0
# Total Unusual Items                                 -197834000.0
# Total Unusual Items Excluding Goodwill              -197834000.0
# Net Income From Continuing Operation Net Minori...  -158856000.0
# Reconciled Depreciation                               38905000.0
# Reconciled Cost Of Revenue                           446295000.0
# EBIT                                                -127595000.0
# Net Interest Income                                  -16171000.0
# Interest Expense                                      16171000.0
# Normalized Income                                    -40155600.0
# Net Income From Continuing And Discontinued Ope...  -158856000.0
# ...
